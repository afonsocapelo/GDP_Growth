# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets

import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
import seaborn as sn
from math import sqrt

from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
import sklearn.metrics as metrics
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
import matplotlib.pyplot as plt
from sklearn.linear_model import RidgeCV, LassoCV,ElasticNetCV

# %%
df = pd.read_excel('C:/Users/Afonso Capelo/Downloads/ndb.h2.xlsx')
df1 = pd.read_excel('C:/Users/Afonso Capelo/Downloads/ndb.h2.xlsx')
df2 = pd.read_excel('C:/Users/Afonso Capelo/Downloads/ndb.h2.xlsx')
df3 = pd.read_excel('C:/Users/Afonso Capelo/Downloads/ndb.h2.xlsx')
df5 = pd.read_excel('C:/Users/Afonso Capelo/Downloads/ndb.h2.xlsx')
df7 = pd.read_excel('C:/Users/Afonso Capelo/Downloads/ndb.h2.xlsx')
df9 = pd.read_excel('C:/Users/Afonso Capelo/Downloads/ndb.h2.xlsx')
df10 = pd.read_excel('C:/Users/Afonso Capelo/Downloads/testdb.xlsx')
df11 = pd.read_excel('C:/Users/Afonso Capelo/Downloads/testdb1.xlsx')

df
# Out:
#     Real GDP growth rate   Exports   Imports   Tourism Balance  \
# 0                   4.40   25065.4   31750.8           1923.31
# 1                   4.81   27758.7   35954.8           2244.82
# 2                   3.91   30465.3   40628.3           2818.78
# 3                   3.82   31751.3   43997.8           2833.47
# 4                   1.94   36443.2   50430.3           3297.60
# 5                   0.77   37505.4   51150.0           3761.56
# 6                  -0.93   38736.0   50239.3           3847.20
# 7                   1.79   40136.3   49413.1           3718.37
# 8                   0.78   42407.6   54182.4           3970.73
# 9                   1.63   43255.3   56782.3           3744.34
# 10                  2.51   50585.5   63526.6           4014.25
# 11                  0.32   55225.5   68037.5           4533.41
# 12                 -3.12   56528.4   73092.7           4501.33
# 13                  1.74   47942.5   59809.8           4195.58
# ...

# %%
df.drop('Real GDP growth rate', inplace=True, axis=1)
df7.drop('Real GDP growth rate', inplace=True, axis=1)

dfy=df1['Real GDP growth rate']

# %%
#Data Collection and Preparation

# %%
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize=(20,20))
sn.heatmap(corr_matrix, annot=True)
plt.show()

# %%
corr_matrix = df.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(np.bool))
upper
# Out:
# C:\Users\Afonso Capelo\AppData\Local\Temp\ipykernel_18348\3287122467.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(np.bool))
#                                                      Exports   Imports  \
#  Exports                                                 NaN  0.923305
#  Imports                                                 NaN       NaN
#  Tourism Balance                                         NaN       NaN
#  Household consumption as % GDP                          NaN       NaN
#  PA Expenditures                                         NaN       NaN
# ...

# %%
drop = [column for column in upper.columns if any(upper[column] >= 0.85)]
df = df.drop(df[drop], axis=1)
drop
# Out:
# [' Imports',
#  ' Tourism Balance',
#  ' PA Expenditures',
#  ' Gross Fixed Capital Formation as % GDP',
#  ' Unemployed population seeking new employment',
#  ' Minimum wage',
#  ' General government spending on health',
#  ' Higher education graduates',
#  ' Enterprises',
#  ' General government revenue',
#  ' Gross electricity generation',
#  ' Expenditure on research and development activities',
#  ' Inventions/patents',
#  ' Investment rate',
#  ' Labour force per inactive person',
#  'General government expenditure on education']

# %%
y_test_predict={}

# %%
#creating data and training set

# %%
Y=dfy
X = df
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
#Linear regression test, we see that is overfitted

# %%
X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# C:\Users\Afonso Capelo\anaconda3\lib\site-packages\scipy\stats\stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Real GDP growth rate   R-squared:                       0.997
# Model:                              OLS   Adj. R-squared:                  0.945
# Method:                   Least Squares   F-statistic:                     19.38
# Date:                  Wed, 23 Nov 2022   Prob (F-statistic):              0.177
# Time:                          00:53:22   Log-Likelihood:                 10.237
# No. Observations:                    18   AIC:                             13.53
# Df Residuals:                         1   BIC:                             28.66
# Df Model:                            16
# Covariance Type:              nonrobust
# ...

# %%
#PCA

# %%
sc = StandardScaler()
X_train1 = sc.fit_transform(X_train)
X_test1 = sc.transform(X_test)

pca = PCA(n_components = 5)
 
X_train1 = pca.fit_transform(X_train1)
X_test1 = pca.transform(X_test1)
 
explained_variance = pca.explained_variance_ratio_

# %%
pcadf=pd.DataFrame(data = X_train1)

# %%
pcadf
# Out:
#        0     1     2     3     4
# 0  -4.22 -1.37  1.67  1.44 -0.60
# 1   4.41 -1.29  0.02  0.19 -0.34
# 2   6.07  0.25  0.81 -2.25 -1.20
# 3  -5.03  3.58 -1.71 -1.71 -0.61
# 4  -5.40  3.89  1.37  0.22  2.17
# 5   0.59 -1.99 -0.71 -0.29  1.65
# 6   1.75 -0.46 -1.87  0.42  1.10
# 7  -3.01 -2.06  3.00  0.70 -0.15
# 8  -1.77 -2.97 -0.06 -1.81  0.55
# 9   4.89 -0.16  0.61 -1.06  0.97
# 10  6.63  4.30  1.44  1.21 -0.86
# 11  3.81 -0.64 -2.45  2.42  0.25
# 12 -5.04  0.89 -1.83  0.32 -1.35
# 13 -3.68 -1.95 -0.29  0.18 -1.57

# %%
#variance explained by pca

# %%
explainedVarience=sum(explained_variance)*100
explainedVarience
# Out:
# 88.95995933574429

# %%
# Linear Regression with PCA test

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train1, y_train)
print('Accuracy on the training subset: {:.3f}'.format(reg.score(X_train1, y_train)))
print('Accuracy on the test subset: {:.3f}'.format(reg.score(X_test1, y_test)))
y_test_predict['linearPCA']=reg.predict(X_test1)
# Out:
# Accuracy on the training subset: 0.877
# Accuracy on the test subset: 0.555

# %%
y1 = Y.values.reshape(-1,1)

# %%
X1 = sc.fit_transform(X)

pca = PCA(n_components = 5)
 
X1 = pca.fit_transform(X1)


X1 = sm.add_constant(X1)
results = sm.OLS(Y, X1).fit()
results.summary()
# Out:
# C:\Users\Afonso Capelo\anaconda3\lib\site-packages\scipy\stats\stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Real GDP growth rate   R-squared:                       0.862
# Model:                              OLS   Adj. R-squared:                  0.805
# Method:                   Least Squares   F-statistic:                     15.01
# Date:                  Wed, 23 Nov 2022   Prob (F-statistic):           8.33e-05
# Time:                          00:54:05   Log-Likelihood:                -23.587
# No. Observations:                    18   AIC:                             59.17
# Df Residuals:                        12   BIC:                             64.52
# Df Model:                             5
# Covariance Type:              nonrobust
# ...

# %%
#GradientBoosting

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

gbr_params = {'n_estimators': 1000,
          'max_depth': 3,
          'min_samples_split': 5,
          'learning_rate': 0.01
          }

reg = GradientBoostingRegressor(**gbr_params)

reg.fit(X_train, y_train)


print("Accuracy on the train subset:: %.3f" % reg.score(X_train, y_train))
print("Accuracy on the test subset:: %.3f" % reg.score(X_test, y_test))

y_test_predict['Gboost']=reg.predict(X_test)
# Out:
# Accuracy on the train subset:: 1.000
# Accuracy on the test subset:: 0.631

# %%
#Random Forest

# %%
reg = RandomForestRegressor(n_estimators=1000, max_depth=3, random_state=0)
reg.fit(X_train, y_train)
print('Accuracy on the training subset: {:.3f}'.format(reg.score(X_train, y_train)))
print('Accuracy on the test subset: {:.3f}'.format(reg.score(X_test, y_test)))
y_test_predict['Rforest']=reg.predict(X_test)
# Out:
# Accuracy on the training subset: 0.918
# Accuracy on the test subset: 0.623

# %%
#Comparing Results

# %%
DicMeasures={}
DicMeasures={'Measures':['MSE','RMSE','MAE','EV','R2']}
for a in y_test_predict.keys():
    DicMeasures[a]= []
    DicMeasures[a].append(round(metrics.mean_absolute_error(y_test, y_test_predict[a]),2))
    DicMeasures[a].append(round(sqrt(metrics.mean_squared_error(y_test, y_test_predict[a])),2))
    DicMeasures[a].append(round(metrics.median_absolute_error(y_test, y_test_predict[a]),2))
    DicMeasures[a].append(round(metrics.explained_variance_score(y_test, y_test_predict[a]),2)) 
    DicMeasures[a].append(round(metrics.r2_score(y_test, y_test_predict[a]),2))
    
df2=pd.DataFrame(data=DicMeasures)
pd.options.display.float_format = '{:.2f}'.format
df2.set_index('Measures').T
# Out:
# Measures   MSE  RMSE  MAE   EV   R2
# linearPCA 1.19  1.42 0.82 0.59 0.55
# Gboost    1.06  1.29 0.68 0.66 0.63
# Rforest   1.15  1.30 1.14 0.63 0.62

# %%
#Now we will test the results with the original dataset

# %%
Y=dfy
X = df3
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
#linear regression with pca

# %%
sc = StandardScaler()
X_train1 = sc.fit_transform(X_train)
X_test1 = sc.transform(X_test)

pca = PCA(n_components = 5)
 
X_train1 = pca.fit_transform(X_train1)
X_test1 = pca.transform(X_test1)
 
explained_variance = pca.explained_variance_ratio_

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train1, y_train)
print('Accuracy on the training subset: {:.3f}'.format(reg.score(X_train1, y_train)))
print('Accuracy on the test subset: {:.3f}'.format(reg.score(X_test1, y_test)))
y_test_predict['linearPCA']=reg.predict(X_test1)
results.summary()
# Out:
# Accuracy on the training subset: 0.948
# Accuracy on the test subset: 0.879
# C:\Users\Afonso Capelo\anaconda3\lib\site-packages\scipy\stats\stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Real GDP growth rate   R-squared:                       0.862
# Model:                              OLS   Adj. R-squared:                  0.805
# Method:                   Least Squares   F-statistic:                     15.01
# Date:                  Wed, 23 Nov 2022   Prob (F-statistic):           8.33e-05
# Time:                          00:57:20   Log-Likelihood:                -23.587
# No. Observations:                    18   AIC:                             59.17
# Df Residuals:                        12   BIC:                             64.52
# ...

# %%
y1 = Y.values.reshape(-1,1)

# %%
X1 = sc.fit_transform(X)

pca = PCA(n_components = 5)
 
X1 = pca.fit_transform(X1)


X1 = sm.add_constant(X1)
results = sm.OLS(Y, X1).fit()
results.summary()
# Out:
# C:\Users\Afonso Capelo\anaconda3\lib\site-packages\scipy\stats\stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Real GDP growth rate   R-squared:                       0.918
# Model:                              OLS   Adj. R-squared:                  0.884
# Method:                   Least Squares   F-statistic:                     26.81
# Date:                  Wed, 23 Nov 2022   Prob (F-statistic):           4.04e-06
# Time:                          00:57:25   Log-Likelihood:                -18.930
# No. Observations:                    18   AIC:                             49.86
# Df Residuals:                        12   BIC:                             55.20
# Df Model:                             5
# Covariance Type:              nonrobust
# ...

# %%
#GradientBoost

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

gbr_params = {'n_estimators': 1000,
          'max_depth': 3,
          'min_samples_split': 5,
          'learning_rate': 0.01
          }

reg = GradientBoostingRegressor(**gbr_params)

reg.fit(X_train, y_train)


print("Accuracy on the train subset:: %.3f" % reg.score(X_train, y_train))
print("Accuracy on the test subset:: %.3f" % reg.score(X_test, y_test))

y_test_predict['Gboost']=reg.predict(X_test)
# Out:
# Accuracy on the train subset:: 1.000
# Accuracy on the test subset:: 0.952

# %%
#RandomForest

# %%
reg = RandomForestRegressor(n_estimators=1000, max_depth=3, random_state=0)
reg.fit(X_train, y_train)
print('Accuracy on the training subset: {:.3f}'.format(reg.score(X_train, y_train)))
print('Accuracy on the test subset: {:.3f}'.format(reg.score(X_test, y_test)))
y_test_predict['Rforest']=reg.predict(X_test)
# Out:
# Accuracy on the training subset: 0.957
# Accuracy on the test subset: 0.841

# %%
#Comparing results with the original dataset

# %%
DicMeasures={}
DicMeasures={'Measures':['MSE','RMSE','MAE','EV','R2']}
for a in y_test_predict.keys():
    DicMeasures[a]= []
    DicMeasures[a].append(round(metrics.mean_absolute_error(y_test, y_test_predict[a]),2))
    DicMeasures[a].append(round(sqrt(metrics.mean_squared_error(y_test, y_test_predict[a])),2))
    DicMeasures[a].append(round(metrics.median_absolute_error(y_test, y_test_predict[a]),2))
    DicMeasures[a].append(round(metrics.explained_variance_score(y_test, y_test_predict[a]),2)) 
    DicMeasures[a].append(round(metrics.r2_score(y_test, y_test_predict[a]),2))
    
df2=pd.DataFrame(data=DicMeasures)
pd.options.display.float_format = '{:.2f}'.format
df2.set_index('Measures').T
# Out:
# Measures   MSE  RMSE  MAE   EV   R2
# linearPCA 0.54  0.74 0.47 0.88 0.88
# Gboost    0.38  0.46 0.40 0.97 0.95
# Rforest   0.73  0.85 0.91 0.86 0.84

# %%
#predicting with the dataset after the colletion and preparation of the data

# %%
reg = RandomForestRegressor(n_estimators=1000, max_depth=3, random_state=0)
X=df
Y=dfy


reg.fit(X, Y)

X3=df10
rf=reg.predict(X3)

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error
X=df
Y=dfy
gbr_params = {'n_estimators': 1000,
          'max_depth': 3,
          'min_samples_split': 5,
          'learning_rate': 0.01,
          'loss': 'ls'}

reg = GradientBoostingRegressor(**gbr_params)

reg.fit(X, Y)

X3=df10

gb=reg.predict(X3)
# Out:
# C:\Users\Afonso Capelo\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(

# %%
pca = PCA(n_components = 5)
reg = linear_model.LinearRegression()
X=df
Y=dfy
reg.fit(X, Y)
X1 = sc.fit_transform(X)


X1 = pca.fit_transform(X1)

X3=df10

X3 = pca.fit_transform(X3)
X4=sc.fit_transform(X3)
results = sm.OLS(y1, X1).fit()
pca=results.predict(X4)

# %%
#predictions graph

# %%
plt.figure(figsize=(12,8))
x=[2015,2016,2017,2018,2019]
y=[1.79,2.02,3.51,2.85,2.68]
plt.scatter(x, y, color="black", label = "Observed GDP Growth")
plt.plot(x, rf, color="green", linewidth=3,label="Random Forest")
plt.plot(x, gb, color="red", linewidth=3,label="Gradient Boost")
plt.plot(x, pca, color="purple", linewidth=3,label="PCA ")
plt.xlabel("Years")
plt.ylabel("GDP Growth")
plt.title("Observed GDP Growth vs Predictions")
plt.xticks()
plt.yticks()
plt.legend()
plt.savefig('gdp_predictions.png', bbox_inches='tight')
plt.show()

# %%
#prediction with the original dataset

# %%
y_test_predict1={}

# %%
reg = RandomForestRegressor(n_estimators=1000, max_depth=3, random_state=0)
X=df7
Y=dfy


reg.fit(X, Y)


X3=df11
rf=reg.predict(X3)
y_test_predict1['rf']=rf

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error
X=df7
Y=dfy
gbr_params = {'n_estimators': 1000,
          'max_depth': 3,
          'min_samples_split': 5,
          'learning_rate': 0.01,
          'loss': 'ls'}

reg = GradientBoostingRegressor(**gbr_params)

reg.fit(X, Y)

X3=df11

gb=reg.predict(X3)
y_test_predict1['GB']=gb
# Out:
# C:\Users\Afonso Capelo\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(

# %%
pca = PCA(n_components = 5)
reg = linear_model.LinearRegression()
X=df7
Y=dfy
reg.fit(X, Y)
X1 = sc.fit_transform(X)
X1

X1 = pca.fit_transform(X1)

X1
X3=df10

X3 = pca.fit_transform(X3)
X4=sc.fit_transform(X3)
results = sm.OLS(y1, X1).fit()
pca1=results.predict(X4)
y_test_predict1['pca']=pca1

# %%
plt.figure(figsize=(12,8))
x=[2015,2016,2017,2018,2019]
y=[1.79,2.02,3.51,2.85,2.68]
plt.scatter(x, y, color="black", label = "Observed GDP Growth")
plt.plot(x, rf, color="green", linewidth=3,label="Random Forest")
plt.plot(x, gb, color="red", linewidth=3,label="Gradient Boost")
plt.plot(x, pca1, color="purple", linewidth=3,label="PCA")
plt.xlabel("Years")
plt.ylabel("GDP Growth")
plt.title("Observed GDP Growth vs Predictions")
plt.xticks()
plt.yticks()
plt.legend()
plt.savefig('gdp_predictions.png', bbox_inches='tight')
plt.show()
